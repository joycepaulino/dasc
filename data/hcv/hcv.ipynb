# %%
# %%bash
# pip3 install matplotlib
# pip3 install pandas
# pip3 install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("HCV-Egy-Data.csv")
df.head()
# Out:
#    Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0    56       1   35      2               1          1          1
# 1    46       1   29      1               2          2          1
# 2    57       1   33      2               2          2          2
# 3    49       2   33      1               2          1          2
# 4    59       1   32      1               1          2          1
#
#    Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  ALT 36  \
# 0                                 2          2                 2  ...       5
# 1                                 2          2                 1  ...      57
# 2                                 1          1                 1  ...       5
# 3                                 1          2                 1  ...      48
# 4                                 2          2                 2  ...      94
#
#    ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  RNA EF  \
# 0       5               5    655330  634536   288194        5       5
# 1     123              44     40620  538635   637056   336804   31085
# 2       5               5    571148  661346        5   735945  558829
# 3      77              33   1041941  449939   585688   744463  582301
# 4      90              30    660410  738756  3731527   338946  242861
#
#    Baseline histological Grading  Baselinehistological staging
# 0                             13                             2
# 1                              4                             2
# 2                              4                             4
# 3                             10                             3
# 4                             11                             1
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 29 columns):
# Age                                 1385 non-null int64
# Gender                              1385 non-null int64
# BMI                                 1385 non-null int64
# Fever                               1385 non-null int64
# Nausea/Vomting                      1385 non-null int64
# Headache                            1385 non-null int64
# Diarrhea                            1385 non-null int64
# Fatigue & generalized bone ache     1385 non-null int64
# Jaundice                            1385 non-null int64
# Epigastric pain                     1385 non-null int64
# WBC                                 1385 non-null int64
# RBC                                 1385 non-null float64
# HGB                                 1385 non-null int64
# Plat                                1385 non-null float64
# AST 1                               1385 non-null int64
# ALT 1                               1385 non-null int64
# ALT4                                1385 non-null float64
# ALT 12                              1385 non-null int64
# ALT 24                              1385 non-null int64
# ALT 36                              1385 non-null int64
# ALT 48                              1385 non-null int64
# ALT after 24 w                      1385 non-null int64
# RNA Base                            1385 non-null int64
# RNA 4                               1385 non-null int64
# RNA 12                              1385 non-null int64
# RNA EOT                             1385 non-null int64
# RNA EF                              1385 non-null int64
# Baseline histological Grading       1385 non-null int64
# Baselinehistological staging        1385 non-null int64
# dtypes: float64(3), int64(26)
# memory usage: 313.9 KB

# %%
description = df.describe().T
description['datatype'] = df.dtypes
columns = list(description.columns)
description = description.loc[:, columns[-1:] + columns[:-1]]
description
# Out:
#                                  datatype   count          mean  \
# Age                                 int64  1385.0  4.631913e+01
# Gender                              int64  1385.0  1.489531e+00
# BMI                                 int64  1385.0  2.860866e+01
# Fever                               int64  1385.0  1.515523e+00
# Nausea/Vomting                      int64  1385.0  1.502527e+00
# Headache                            int64  1385.0  1.496029e+00
# Diarrhea                            int64  1385.0  1.502527e+00
# Fatigue & generalized bone ache     int64  1385.0  1.498917e+00
# Jaundice                            int64  1385.0  1.501083e+00
# Epigastric pain                     int64  1385.0  1.503971e+00
# WBC                                 int64  1385.0  7.533386e+03
# RBC                               float64  1385.0  4.422130e+06
# HGB                                 int64  1385.0  1.258773e+01
# Plat                              float64  1385.0  1.583481e+05
# AST 1                               int64  1385.0  8.277473e+01
# ALT 1                               int64  1385.0  8.391625e+01
# ALT4                              float64  1385.0  8.340578e+01
# ALT 12                              int64  1385.0  8.351047e+01
# ALT 24                              int64  1385.0  8.370903e+01
# ALT 36                              int64  1385.0  8.311769e+01
# ALT 48                              int64  1385.0  8.362960e+01
# ALT after 24 w                      int64  1385.0  3.343827e+01
# RNA Base                            int64  1385.0  5.909512e+05
# RNA 4                               int64  1385.0  6.008956e+05
# RNA 12                              int64  1385.0  2.887536e+05
# RNA EOT                             int64  1385.0  2.876603e+05
# RNA EF                              int64  1385.0  2.913783e+05
# Baseline histological Grading       int64  1385.0  9.761733e+00
# Baselinehistological staging        int64  1385.0  2.536462e+00
#
#                                             std        min        25%  \
# Age                                    8.781506       32.0       39.0
# Gender                                 0.500071        1.0        1.0
# BMI                                    4.076215       22.0       25.0
# Fever                                  0.499939        1.0        1.0
# Nausea/Vomting                         0.500174        1.0        1.0
# Headache                               0.500165        1.0        1.0
# Diarrhea                               0.500174        1.0        1.0
# Fatigue & generalized bone ache        0.500179        1.0        1.0
# Jaundice                               0.500179        1.0        1.0
# Epigastric pain                        0.500165        1.0        1.0
# WBC                                 2668.220333     2991.0     5219.0
# RBC                               346357.711599  3816422.0  4121374.0
# HGB                                    1.713511       10.0       11.0
# Plat                               38794.785550    93013.0   124479.0
# AST 1                                 25.993242       39.0       60.0
# ALT 1                                 25.922800       39.0       62.0
# ALT4                                  26.529730       39.0       61.0
# ALT 12                                26.064478       39.0       60.0
# ALT 24                                26.205994       39.0       61.0
# ALT 36                                26.399031        5.0       61.0
# ALT 48                                26.223955        5.0       61.0
# ALT after 24 w                         7.073569        5.0       28.0
# RNA Base                          353935.357602       11.0   269253.0
# RNA 4                             362315.132786        5.0   270893.0
# RNA 12                            285350.674511        5.0        5.0
# RNA EOT                           264559.525070        5.0        5.0
# RNA EF                            267700.691713        5.0        5.0
# Baseline histological Grading          4.023896        3.0        6.0
# Baselinehistological staging           1.121392        1.0        2.0
#
#                                         50%        75%        max
# Age                                    46.0       54.0       61.0
# Gender                                  1.0        2.0        2.0
# BMI                                    29.0       32.0       35.0
# Fever                                   2.0        2.0        2.0
# Nausea/Vomting                          2.0        2.0        2.0
# Headache                                1.0        2.0        2.0
# Diarrhea                                2.0        2.0        2.0
# Fatigue & generalized bone ache         1.0        2.0        2.0
# Jaundice                                2.0        2.0        2.0
# Epigastric pain                         2.0        2.0        2.0
# WBC                                  7498.0     9902.0    12101.0
# RBC                               4438465.0  4721279.0  5018451.0
# HGB                                    13.0       14.0       15.0
# Plat                               157916.0   190314.0   226464.0
# AST 1                                  83.0      105.0      128.0
# ALT 1                                  83.0      106.0      128.0
# ALT4                                   82.0      107.0      128.0
# ALT 12                                 84.0      106.0      128.0
# ALT 24                                 83.0      107.0      128.0
# ALT 36                                 84.0      106.0      128.0
# ALT 48                                 83.0      106.0      128.0
# ALT after 24 w                         34.0       40.0       45.0
# RNA Base                           593103.0   886791.0  1201086.0
# RNA 4                              597869.0   909093.0  1201715.0
# RNA 12                             234359.0   524819.0  3731527.0
# RNA EOT                            251376.0   517806.0   808450.0
# RNA EF                             244049.0   527864.0   810333.0
# Baseline histological Grading          10.0       13.0       16.0
# Baselinehistological staging            3.0        4.0        4.0
